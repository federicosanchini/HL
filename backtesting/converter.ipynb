# %%
import pandas as pd

input_file = "../data/metamodel.parquet"
output_file = "../data/ranks_crowdcent.csv"

df = pd.read_parquet(input_file)
df.to_csv(output_file, index=False)

print("File converted successfully!")
# Out:
# File converted successfully!
