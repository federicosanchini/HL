# %%
import time
import requests
import pandas as pd
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional, Set

API_URL = "https://api.hyperliquid.xyz/info"

# -------------------------------------------------------------------------
# LISTA TICKER
# -------------------------------------------------------------------------
tickers = [
    'ATOM','REQ','CRV','MAVIA','SAGA','NEAR','MORPHO','MANTA','MOVE','XAI',
    'ETC','DOGE','SOPH','CELO','MAV','POPCAT','SCR','COMP','GMT','SOL','IMX',
    'JUP','RUNE','LAUNCHCOIN','UMA','TRB','USTC','AIXBT','IOTA','VIRTUAL',
    'ALGO','GMX','ANIME','BCH','BIO','BSV','NXPC','MOODENG','TNSR','HBAR',
    'SNX','ZEREBRO','HYPER','SAND','BERA','PURR','GAS','LDO','ONDO','DYDX',
    'FTT','TON','EIGEN','LTC','BLAST','AI16Z','OMNI','AAVE','OGN','SUI',
    'MEME','FXS','NEIROETH','NIL','CFX','ME','XRP','TIA','BNB','NOT','IP',
    'OM','TAO','OP','CAKE','AVAX','kPEPE','GALA','MNT','BOME','SUPER','SEI',
    'VINE','KAS','BABY','STX','S','FARTCOIN','STG','RENDER','ENA','LINK',
    'ARB','ARK','BIGTIME','BTC','ETH','RSR','kDOGS','BRETT','BANANA','XLM',
    'INJ','ENS','AR','DOT','SPX','ETHFI','PAXG','kLUNC','GOAT','kSHIB','FIL',
    'MEW','STRK','TRX','ZK','KAITO','PENGU','kBONK','VVV','ORDI','INIT','APT',
    'REZ','LAYER','ZEN','SUSHI','kFLOKI','ADA','kNEIRO','PEOPLE','ZORA',
    'PENDLE','APE','HYPE','FET','CHILLGUY','MELANIA','GRIFFAIN','PNUT','DOOD',
    'WIF','ACE','ZETA','TRUMP','NEO','JTO','YGG','ZRO','PROMPT','WLD','W',
    'MERL','BLUR','UNI','DYM','MINA','MKR','POLYX','POL','IO','TURBO','PYTH',
    'USUAL','GRASS','ALT','HMSTR','WCT','SYRUP','RESOLV','PROVE','YZY','WLFI',
    'TST','PUMP','LINEA','SKY','ASTER','0G','STBL','AVNT','XPL','ZEC','ICP'
]


# -------------------------------------------------------------------------
# FUNZIONI DI SUPPORTO
# -------------------------------------------------------------------------

def safe_post(payload: dict,
              max_retries: int = 5,
              base_delay: float = 1.0) -> Optional[requests.Response]:
    """
    Esegue POST verso l'info endpoint gestendo rate-limit (429) con retry
    e backoff esponenziale.
    """
    attempt = 0
    delay = base_delay

    while True:
        try:
            r = requests.post(API_URL, json=payload, timeout=10)
            # Gestione rate limit
            if r.status_code == 429:
                attempt += 1
                if attempt > max_retries:
                    print(f"Rate limit esaurito per payload={payload.get('type')} {payload.get('coin')}, rinuncio.")
                    return None
                print(f"Rate limited (429) per {payload.get('type')} {payload.get('coin')}, retry fra {delay:.1f}s...")
                time.sleep(delay)
                delay *= 2
                continue

            r.raise_for_status()
            return r

        except Exception as e:
            attempt += 1
            if attempt > max_retries:
                print(f"HTTP error definitivo per {payload.get('type')} {payload.get('coin')}: {e}")
                return None
            print(f"HTTP error per {payload.get('type')} {payload.get('coin')}: {e}, retry fra {delay:.1f}s...")
            time.sleep(delay)
            delay *= 2


def get_perp_universe() -> Optional[Set[str]]:
    """
    Restituisce l'insieme dei nomi dei perps (campo 'name' in 'universe')
    usando type: 'meta'. Se fallisce, restituisce None.
    """
    payload = {"type": "meta"}
    r = safe_post(payload)
    if r is None:
        print("Impossibile ottenere la meta; uso la lista ticker così com'è.")
        return None

    try:
        meta = r.json()
    except Exception as e:
        print(f"Errore parsing meta JSON: {e} | raw: {r.text[:200]}")
        return None

    universe = meta.get("universe", [])
    names = {c.get("name") for c in universe if isinstance(c, dict) and "name" in c}
    return names


def detect_listing_time_ms(coin: str, end_ms: int) -> Optional[int]:
    """
    Stima la 'listing date' del perp come il timestamp del primo record
    disponibile in fundingHistory (più vecchio).
    """
    payload = {
        "type": "fundingHistory",
        "coin": coin,
        "startTime": 0,
        "endTime": end_ms,
    }

    r = safe_post(payload)
    if r is None:
        print(f"Impossibile detectare listing per {coin} (safe_post fallita).")
        return None

    try:
        data = r.json()
    except Exception as e:
        print(f"JSON decode error per listing {coin}: {e} | raw: {r.text[:200]}")
        return None

    if not isinstance(data, list) or len(data) == 0:
        # Nessun funding registrato per questo coin
        return None

    first = data[0]
    t = first.get("time")
    if t is None:
        return None

    return int(t)


def fetch_funding_all(coin: str,
                      start_ms: int,
                      end_ms: int) -> pd.DataFrame:
    """
    Scarica tutto lo storico di funding per `coin` tra start_ms ed end_ms,
    paginando, e restituisce TUTTI i funding orari (nessun filtro 8h).
    """
    all_rows = []
    cursor = start_ms

    while True:
        payload = {
            "type": "fundingHistory",
            "coin": coin,
            "startTime": cursor,
            "endTime": end_ms,
        }

        r = safe_post(payload)
        if r is None:
            # Se safe_post ha fallito dopo i retry, restituisco quello che ho
            break

        try:
            data = r.json()
        except Exception as e:
            print(f"JSON decode error per {coin} a cursor={cursor}: {e} | raw: {r.text[:200]}")
            break

        if not isinstance(data, list) or len(data) == 0:
            # Fine dati
            break

        all_rows.extend(data)

        # Se meno di 500 elementi, non ci sono altre pagine
        if len(data) < 500:
            break

        last_time = data[-1].get("time")
        if last_time is None or last_time <= cursor:
            print(f"Anomalia time per {coin}: last_time={last_time}, cursor={cursor}. Stop paginazione.")
            break

        cursor = last_time + 1  # +1 ms per non duplicare l'ultima entry

        # Piccolo sleep fra le pagine per non abusare
        time.sleep(0.05)

    if not all_rows:
        return pd.DataFrame()

    df = pd.DataFrame(all_rows)

    if "time" not in df.columns or "fundingRate" not in df.columns:
        print(f"Risposta inattesa per {coin}, colonne: {df.columns.tolist()}")
        return pd.DataFrame()

    df["time"] = pd.to_datetime(df["time"], unit="ms", utc=True)
    df["fundingRate"] = pd.to_numeric(df["fundingRate"], errors="coerce")

    # QUI NON FILTRIAMO PIÙ: restituiamo TUTTE le ore
    df_full = df[["time", "fundingRate"]].copy()

    return df_full




# -------------------------------------------------------------------------
# RESUME / APPEND SU CSV ESISTENTE
# -------------------------------------------------------------------------

DATA_DIR = Path("../data")
RESUME_EPSILON_MS = 1  # evita di riscaricare l'ultima riga già salvata


def load_existing_csv(out_path: Path) -> pd.DataFrame:
    """
    Carica il CSV già presente in data/, se esiste.
    La colonna time viene normalizzata in UTC per calcolare il resume.
    """
    if not out_path.exists():
        return pd.DataFrame()

    try:
        df = pd.read_csv(out_path)
    except pd.errors.EmptyDataError:
        return pd.DataFrame()

    if "time" in df.columns:
        df["time"] = pd.to_datetime(df["time"], utc=True, errors="coerce")
        df = df.dropna(subset=["time"])

    return df


def get_last_time_by_perp(existing_df: pd.DataFrame) -> dict:
    """
    Restituisce, per ogni perp, l'ultimo timestamp già salvato.
    Così ogni ticker riparte dal proprio ultimo dato, non da una data globale.
    """
    required_cols = {"perp", "time"}
    if existing_df.empty or not required_cols.issubset(existing_df.columns):
        return {}

    return existing_df.groupby("perp")["time"].max().to_dict()


def ts_to_ms(ts) -> int:
    """Converte un pandas/datetime timestamp in millisecondi Unix."""
    return int(pd.Timestamp(ts).timestamp() * 1000)


def append_dedup_and_save(
    new_df: pd.DataFrame,
    existing_df: pd.DataFrame,
    out_path: Path,
    dedup_cols=("perp", "time"),
) -> int:
    """
    Appende i nuovi dati ai vecchi, rimuove eventuali duplicati e salva in data/.
    """
    DATA_DIR.mkdir(parents=True, exist_ok=True)

    if existing_df.empty:
        combined = new_df.copy()
    else:
        combined = pd.concat([existing_df, new_df], ignore_index=True)

    combined["time"] = pd.to_datetime(combined["time"], utc=True, errors="coerce")
    combined = combined.dropna(subset=["perp", "time"])
    combined = (
        combined
        .drop_duplicates(subset=list(dedup_cols), keep="last")
        .sort_values(["perp", "time"])
    )

    combined.to_csv(out_path, index=False)
    return len(combined)


# -------------------------------------------------------------------------
# MAIN
# -------------------------------------------------------------------------

def main():
    # Start "globale" che vuoi usare come minimo
    global_start = datetime(2025, 6, 5, tzinfo=timezone.utc)
    now = datetime.now(timezone.utc)

    global_start_ms = int(global_start.timestamp() * 1000)
    end_ms = int(now.timestamp() * 1000)

    out_name = "all_perps_hourly_funding.csv"
    out_path = DATA_DIR / out_name
    existing_df = load_existing_csv(out_path)
    last_time_by_perp = get_last_time_by_perp(existing_df)

    if existing_df.empty:
        print(f"CSV esistente non trovato o vuoto: {out_path}. Download completo dal global_start.")
    else:
        print(
            f"CSV esistente: {out_path} | righe={len(existing_df)} | "
            f"ultimo time={existing_df['time'].max()}"
        )

    # 1) Prendi l'universo dei perps da HL (per sicurezza)
    perp_universe = get_perp_universe()
    if perp_universe is not None:
        valid_tickers = [t for t in tickers if t in perp_universe]
        missing = sorted(set(tickers) - perp_universe)
        if missing:
            print("Ticker non trovati in universe (probabilmente non perps o nomi diversi):")
            print(", ".join(missing))
    else:
        valid_tickers = tickers

    funding_rows = []

    for ticker in valid_tickers:
        print(f"\n=== {ticker} ===")

        # 2) Detect listing time per questo perp
        listing_ms = detect_listing_time_ms(ticker, end_ms)
        if listing_ms is None:
            print(f"⚠️ Nessun funding (o impossibile trovare listing) per {ticker} — skipped")
            time.sleep(0.2)
            continue

        # Start effettivo: max(start globale, listing, ultimo dato già salvato + 1 ms)
        start_ms = max(global_start_ms, listing_ms)
        last_saved_time = last_time_by_perp.get(ticker)

        if last_saved_time is not None and not pd.isna(last_saved_time):
            resume_ms = ts_to_ms(last_saved_time) + RESUME_EPSILON_MS
            start_ms = max(start_ms, resume_ms)

        if start_ms >= end_ms:
            print(f"Già aggiornato fino a {last_saved_time} — skipped")
            time.sleep(0.2)
            continue

        print(
            f"Listing {ticker}: {datetime.fromtimestamp(listing_ms/1000, tz=timezone.utc)} "
            f" | ultimo salvato: {last_saved_time} "
            f" | start effettivo: {datetime.fromtimestamp(start_ms/1000, tz=timezone.utc)}"
        )

        # 3) Scarica solo il funding mancante da start_ms a end_ms con paginazione
        df_f = fetch_funding_all(ticker, start_ms, end_ms)

        if df_f.empty:
            print(f"⚠️ Nessun funding in range per {ticker} — skipped")
            time.sleep(0.2)
            continue

        for _, row in df_f.iterrows():
            funding_rows.append({
                "perp": ticker,
                "time": row["time"],
                "fundingRate": row["fundingRate"],
            })

        # Piccolo sleep tra un perp e l'altro per non prendere troppi 429
        time.sleep(0.2)

    if not funding_rows:
        print("Nessun nuovo dato di funding da scaricare.")
        return

    funding_df = pd.DataFrame(funding_rows)
    funding_df = funding_df.sort_values(["perp", "time"])

    total_rows = append_dedup_and_save(funding_df, existing_df, out_path)
    print(f"\n✔️ Appended + deduplicated → {out_path} | righe totali={total_rows} | nuove righe={len(funding_df)}")


if __name__ == "__main__":
    main()
# Out:
# CSV esistente: ../data/all_perps_hourly_funding.csv | righe=812338 | ultimo time=2025-12-14 12:00:00.014000+00:00
#
# === ATOM ===
# Listing ATOM: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === REQ ===
# Listing REQ: 2023-10-11 14:00:00.116000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === CRV ===
# Listing CRV: 2023-05-15 16:00:00.409000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MAVIA ===
# Listing MAVIA: 2024-02-06 23:00:00.019000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SAGA ===
# Listing SAGA: 2024-04-21 07:00:00.074000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === NEAR ===
# Listing NEAR: 2023-11-01 17:00:00.031000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MORPHO ===
# Listing MORPHO: 2025-01-17 09:00:00.042000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MANTA ===
# Listing MANTA: 2024-01-18 22:00:00.307000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MOVE ===
# Listing MOVE: 2024-12-11 05:00:00.032000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === XAI ===
# Listing XAI: 2024-01-15 18:00:00.091000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ETC ===
# Listing ETC: 2024-01-12 01:00:00.061000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === DOGE ===
# Listing DOGE: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SOPH ===
# Listing SOPH: 2025-05-28 15:00:00.044000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === CELO ===
# Listing CELO: 2024-09-25 06:00:00.156000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MAV ===
# Listing MAV: 2023-12-20 13:00:00.097000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory MAV, retry fra 1.0s...
# Rate limited (429) per fundingHistory MAV, retry fra 1.0s...
#
# === POPCAT ===
# Listing POPCAT: 2024-04-28 08:00:00.161000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory POPCAT, retry fra 1.0s...
# Rate limited (429) per fundingHistory POPCAT, retry fra 1.0s...
#
# === SCR ===
# Listing SCR: 2024-10-09 04:00:00.049000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === COMP ===
# Listing COMP: 2023-07-18 00:00:00.105000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === GMT ===
# Listing GMT: 2023-11-26 18:00:00.237000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SOL ===
# Listing SOL: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === IMX ===
# Listing IMX: 2023-11-17 16:00:00.047000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === JUP ===
# Listing JUP: 2023-12-03 01:00:00.070000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === RUNE ===
# Listing RUNE: 2023-08-15 14:00:00.709000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === LAUNCHCOIN ===
# Listing LAUNCHCOIN: 2025-05-14 15:00:00.064000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === UMA ===
# Listing UMA: 2024-01-19 04:00:00.097000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory UMA, retry fra 1.0s...
# Rate limited (429) per fundingHistory UMA, retry fra 2.0s...
# Rate limited (429) per fundingHistory UMA, retry fra 4.0s...
# Rate limited (429) per fundingHistory UMA, retry fra 1.0s...
# Rate limited (429) per fundingHistory UMA, retry fra 2.0s...
#
# === TRB ===
# Listing TRB: 2023-09-17 03:00:00.140000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === USTC ===
# Listing USTC: 2023-11-27 16:00:00.217000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AIXBT ===
# Listing AIXBT: 2025-01-01 05:00:00.170000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === IOTA ===
# Listing IOTA: 2024-12-04 13:00:00.060000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === VIRTUAL ===
# Listing VIRTUAL: 2024-12-16 05:00:00.134000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ALGO ===
# Listing ALGO: 2024-12-04 13:00:00.060000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === GMX ===
# Listing GMX: 2023-05-25 00:00:00.233000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ANIME ===
# Listing ANIME: 2025-01-21 16:00:00.106000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BCH ===
# Listing BCH: 2023-06-30 03:00:00.005000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory BCH, retry fra 1.0s...
# Rate limited (429) per fundingHistory BCH, retry fra 1.0s...
# Rate limited (429) per fundingHistory BCH, retry fra 2.0s...
#
# === BIO ===
# Listing BIO: 2025-01-03 14:00:00.035000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BSV ===
# Listing BSV: 2023-10-20 04:00:00.083000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === NXPC ===
# Listing NXPC: 2025-05-15 09:00:00.016000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MOODENG ===
# Listing MOODENG: 2024-10-25 10:00:00.122000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TNSR ===
# Listing TNSR: 2024-04-08 22:00:00.272000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === HBAR ===
# Listing HBAR: 2024-04-24 06:00:00.184000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SNX ===
# Listing SNX: 2023-05-25 00:00:00.233000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZEREBRO ===
# Listing ZEREBRO: 2025-01-02 14:00:00.005000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === HYPER ===
# Listing HYPER: 2025-04-22 16:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory HYPER, retry fra 1.0s...
# Rate limited (429) per fundingHistory HYPER, retry fra 1.0s...
#
# === SAND ===
# Listing SAND: 2024-12-04 13:00:00.060000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BERA ===
# Listing BERA: 2025-02-06 14:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PURR ===
# Listing PURR: 2024-11-04 10:00:00.074000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === GAS ===
# Listing GAS: 2023-10-24 15:00:00.153000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === LDO ===
# Listing LDO: 2023-05-16 00:00:00.447000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ONDO ===
# Listing ONDO: 2024-01-20 15:00:00.040000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === DYDX ===
# Listing DYDX: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === FTT ===
# Listing FTT: 2023-09-25 13:00:00.109000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TON ===
# Listing TON: 2023-10-22 06:00:00.056000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === EIGEN ===
# Listing EIGEN: 2024-04-30 04:00:00.010000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory EIGEN, retry fra 1.0s...
#
# === LTC ===
# Listing LTC: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BLAST ===
# Listing BLAST: 2024-06-26 16:00:00.152000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AI16Z ===
# Listing AI16Z: 2025-01-01 05:00:00.170000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === OMNI ===
# Listing OMNI: 2024-04-29 03:00:00.177000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AAVE ===
# Listing AAVE: 2023-07-18 00:00:00.105000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === OGN ===
# Listing OGN: 2023-10-01 03:00:00.018000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SUI ===
# Listing SUI: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory SUI, retry fra 1.0s...
# Rate limited (429) per fundingHistory SUI, retry fra 2.0s...
# Rate limited (429) per fundingHistory SUI, retry fra 4.0s...
#
# === MEME ===
# Listing MEME: 2023-11-03 15:00:00.120000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory MEME, retry fra 1.0s...
# Rate limited (429) per fundingHistory MEME, retry fra 2.0s...
#
# === FXS ===
# Listing FXS: 2023-07-30 21:00:00.046000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === NEIROETH ===
# Listing NEIROETH: 2024-10-23 13:00:00.095000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === NIL ===
# Listing NIL: 2025-03-24 14:00:00.065000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === CFX ===
# Listing CFX: 2023-05-25 00:00:00.233000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ME ===
# Listing ME: 2024-12-10 15:00:00.055000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === XRP ===
# Listing XRP: 2023-06-18 00:00:00.182000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TIA ===
# Listing TIA: 2023-10-19 23:00:00.093000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BNB ===
# Listing BNB: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory BNB, retry fra 1.0s...
#
# === NOT ===
# Rate limited (429) per fundingHistory NOT, retry fra 1.0s...
# Listing NOT: 2024-05-17 04:00:00.104000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory NOT, retry fra 1.0s...
# Rate limited (429) per fundingHistory NOT, retry fra 2.0s...
#
# === IP ===
# Listing IP: 2025-02-13 10:00:00.004000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === OM ===
# Listing OM: 2025-02-16 16:00:00.015000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TAO ===
# Listing TAO: 2024-02-19 14:00:00.174000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === OP ===
# Listing OP: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === CAKE ===
# Listing CAKE: 2023-12-30 15:00:00.061000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AVAX ===
# Listing AVAX: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kPEPE ===
# Listing kPEPE: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === GALA ===
# Listing GALA: 2023-12-05 20:00:00.334000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MNT ===
# Listing MNT: 2024-04-05 02:00:00.106000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory MNT, retry fra 1.0s...
# Rate limited (429) per fundingHistory MNT, retry fra 2.0s...
#
# === BOME ===
# Listing BOME: 2024-03-15 18:00:00.168000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SUPER ===
# Listing SUPER: 2023-11-26 18:00:00.237000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SEI ===
# Listing SEI: 2023-08-15 13:00:00.148000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === VINE ===
# Listing VINE: 2025-01-23 16:00:00.035000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === KAS ===
# Listing KAS: 2023-10-12 18:00:00.059000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BABY ===
# Listing BABY: 2025-04-12 03:00:00.069000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory BABY, retry fra 1.0s...
# Rate limited (429) per fundingHistory BABY, retry fra 1.0s...
# Rate limited (429) per fundingHistory BABY, retry fra 2.0s...
#
# === STX ===
# Rate limited (429) per fundingHistory STX, retry fra 1.0s...
# Rate limited (429) per fundingHistory STX, retry fra 2.0s...
# Listing STX: 2023-05-18 08:00:00.038000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory STX, retry fra 1.0s...
# Rate limited (429) per fundingHistory STX, retry fra 1.0s...
# Rate limited (429) per fundingHistory STX, retry fra 1.0s...
#
# === S ===
# Rate limited (429) per fundingHistory S, retry fra 1.0s...
# Listing S: 2025-01-17 08:00:00.050000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === FARTCOIN ===
# Listing FARTCOIN: 2024-12-20 12:00:00.134000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === STG ===
# Listing STG: 2023-10-26 16:00:00.046000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === RENDER ===
# Listing RENDER: 2024-07-31 11:00:00.012000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ENA ===
# Listing ENA: 2024-04-02 14:00:00.220000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === LINK ===
# Listing LINK: 2023-05-18 08:00:00.038000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ARB ===
# Listing ARB: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory ARB, retry fra 1.0s...
# Rate limited (429) per fundingHistory ARB, retry fra 2.0s...
# Rate limited (429) per fundingHistory ARB, retry fra 4.0s...
# Rate limited (429) per fundingHistory ARB, retry fra 1.0s...
# Rate limited (429) per fundingHistory ARB, retry fra 2.0s...
# Rate limited (429) per fundingHistory ARB, retry fra 4.0s...
#
# === ARK ===
# Listing ARK: 2023-10-06 14:00:00.082000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BIGTIME ===
# Listing BIGTIME: 2023-10-11 18:00:00.118000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BTC ===
# Listing BTC: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ETH ===
# Listing ETH: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === RSR ===
# Listing RSR: 2023-12-05 20:00:00.334000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kDOGS ===
# Listing kDOGS: 2024-09-03 06:00:00.070000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BRETT ===
# Listing BRETT: 2024-06-11 13:00:00.088000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BANANA ===
# Listing BANANA: 2023-09-15 12:00:00.183000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === XLM ===
# Listing XLM: 2024-11-23 03:00:00.022000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory XLM, retry fra 1.0s...
# Rate limited (429) per fundingHistory XLM, retry fra 2.0s...
# Rate limited (429) per fundingHistory XLM, retry fra 4.0s...
#
# === INJ ===
# Listing INJ: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ENS ===
# Listing ENS: 2024-01-05 15:00:00.188000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AR ===
# Listing AR: 2024-02-28 05:00:00.097000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === DOT ===
# Listing DOT: 2023-09-12 12:00:00.186000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SPX ===
# Listing SPX: 2025-01-07 06:00:00.005000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ETHFI ===
# Listing ETHFI: 2024-03-21 01:00:00.191000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PAXG ===
# Listing PAXG: 2025-04-06 16:00:00.028000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kLUNC ===
# Listing kLUNC: 2023-12-05 20:00:00.334000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory kLUNC, retry fra 1.0s...
#
# === GOAT ===
# Listing GOAT: 2024-10-23 13:00:00.095000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory GOAT, retry fra 1.0s...
# Rate limited (429) per fundingHistory GOAT, retry fra 2.0s...
#
# === kSHIB ===
# Listing kSHIB: 2023-08-11 23:00:00.106000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === FIL ===
# Listing FIL: 2023-11-14 04:00:00.431000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MEW ===
# Listing MEW: 2024-07-23 16:00:00.045000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === STRK ===
# Listing STRK: 2024-02-14 15:00:00.050000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TRX ===
# Listing TRX: 2023-08-06 16:00:00.190000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZK ===
# Listing ZK: 2024-06-12 12:00:00.035000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === KAITO ===
# Listing KAITO: 2025-02-20 14:00:00.075000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PENGU ===
# Listing PENGU: 2024-12-17 15:00:00.051000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kBONK ===
# Listing kBONK: 2023-11-20 00:00:00.148000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === VVV ===
# Listing VVV: 2025-01-28 01:00:00.099000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ORDI ===
# Listing ORDI: 2023-11-07 17:00:00.370000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === INIT ===
# Listing INIT: 2025-04-24 12:00:00.015000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === APT ===
# Listing APT: 2023-06-30 03:00:00.005000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === REZ ===
# Listing REZ: 2024-04-30 13:00:00.169000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === LAYER ===
# Listing LAYER: 2025-02-11 16:00:00.035000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZEN ===
# Listing ZEN: 2023-11-09 15:00:00.315000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SUSHI ===
# Listing SUSHI: 2023-11-17 16:00:00.047000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kFLOKI ===
# Listing kFLOKI: 2024-03-12 00:00:00.024000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ADA ===
# Listing ADA: 2023-10-22 06:00:00.056000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === kNEIRO ===
# Listing kNEIRO: 2024-10-23 13:00:00.095000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PEOPLE ===
# Listing PEOPLE: 2024-01-03 17:00:00.035000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZORA ===
# Listing ZORA: 2025-04-23 15:00:00.032000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PENDLE ===
# Listing PENDLE: 2023-10-26 16:00:00.046000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === APE ===
# Listing APE: 2023-05-12 00:00:00.048000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === HYPE ===
# Listing HYPE: 2024-12-05 10:00:00.004000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === FET ===
# Listing FET: 2023-10-26 16:00:00.046000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === CHILLGUY ===
# Listing CHILLGUY: 2024-11-25 06:00:00.056000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MELANIA ===
# Listing MELANIA: 2025-01-20 01:00:00.184000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === GRIFFAIN ===
# Listing GRIFFAIN: 2025-01-07 06:00:00.005000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PNUT ===
# Listing PNUT: 2024-11-14 04:00:00.090000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === DOOD ===
# Listing DOOD: 2025-05-09 14:00:00.033000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === WIF ===
# Listing WIF: 2023-12-22 16:00:00.182000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ACE ===
# Listing ACE: 2023-12-18 14:00:00.021000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZETA ===
# Listing ZETA: 2024-02-02 01:00:00.381000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TRUMP ===
# Listing TRUMP: 2025-01-18 06:00:00.140000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory TRUMP, retry fra 1.0s...
# Rate limited (429) per fundingHistory TRUMP, retry fra 1.0s...
# Rate limited (429) per fundingHistory TRUMP, retry fra 2.0s...
#
# === NEO ===
# Listing NEO: 2023-11-09 15:00:00.315000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory NEO, retry fra 1.0s...
#
# === JTO ===
# Listing JTO: 2023-12-07 17:00:00.024000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === YGG ===
# Listing YGG: 2023-08-06 16:00:00.190000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZRO ===
# Listing ZRO: 2023-09-07 03:00:00.082000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PROMPT ===
# Listing PROMPT: 2025-04-12 03:00:00.069000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === WLD ===
# Listing WLD: 2023-07-24 14:00:00.105000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === W ===
# Listing W: 2024-02-07 18:00:00.192000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MERL ===
# Listing MERL: 2024-04-23 15:00:00.010000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === BLUR ===
# Listing BLUR: 2023-10-18 18:00:00.137000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === UNI ===
# Listing UNI: 2023-08-11 23:00:00.106000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory UNI, retry fra 1.0s...
#
# === DYM ===
# Rate limited (429) per fundingHistory DYM, retry fra 1.0s...
# Listing DYM: 2024-02-06 18:00:00.264000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MINA ===
# Listing MINA: 2023-10-24 15:00:00.153000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === MKR ===
# Listing MKR: 2023-07-21 05:00:00.008000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === POLYX ===
# Listing POLYX: 2023-10-24 15:00:00.153000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === POL ===
# Listing POL: 2024-09-17 07:00:00.061000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === IO ===
# Listing IO: 2024-06-12 03:00:00.066000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TURBO ===
# Listing TURBO: 2024-05-31 16:00:00.124000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PYTH ===
# Listing PYTH: 2023-11-14 23:00:00.033000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === USUAL ===
# Listing USUAL: 2024-12-18 17:00:00.133000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory USUAL, retry fra 1.0s...
#
# === GRASS ===
# Listing GRASS: 2024-10-28 15:00:00.092000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory GRASS, retry fra 1.0s...
#
# === ALT ===
# Listing ALT: 2024-01-25 15:00:00.108000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === HMSTR ===
# Listing HMSTR: 2024-09-27 05:00:00.006000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === WCT ===
# Listing WCT: 2025-04-15 15:00:00.096000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SYRUP ===
# Listing SYRUP: 2025-06-26 06:00:00.042000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === RESOLV ===
# Listing RESOLV: 2025-06-10 15:00:00.028000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === PROVE ===
# Listing PROVE: 2025-08-06 04:00:00.091000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === YZY ===
# Listing YZY: 2025-08-21 04:00:00.072000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === WLFI ===
# Listing WLFI: 2025-08-23 11:00:00.030000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === TST ===
# Listing TST: 2025-02-09 12:00:00.016000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory TST, retry fra 1.0s...
# Rate limited (429) per fundingHistory TST, retry fra 1.0s...
# Rate limited (429) per fundingHistory TST, retry fra 2.0s...
#
# === PUMP ===
# Listing PUMP: 2025-07-10 04:00:00.033000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === LINEA ===
# Listing LINEA: 2025-09-01 10:00:00.070000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === SKY ===
# Listing SKY: 2025-09-17 06:00:00.012000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ASTER ===
# Listing ASTER: 2025-09-19 11:00:00.063000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === 0G ===
# Listing 0G: 2025-09-22 11:00:00.090000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === STBL ===
# Listing STBL: 2025-09-22 04:00:00.033000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === AVNT ===
# Listing AVNT: 2025-09-21 08:00:00.018000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === XPL ===
# Listing XPL: 2025-08-22 10:00:00.030000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# === ZEC ===
# Listing ZEC: 2025-10-02 14:00:00.020000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
# Rate limited (429) per fundingHistory ZEC, retry fra 1.0s...
# Rate limited (429) per fundingHistory ZEC, retry fra 2.0s...
#
# === ICP ===
# Listing ICP: 2025-11-08 04:00:00.013000+00:00  | ultimo salvato: 2025-12-14 12:00:00.014000+00:00  | start effettivo: 2025-12-14 12:00:00.015000+00:00
#
# ✔️ Appended + deduplicated → ../data/all_perps_hourly_funding.csv | righe totali=1421173 | nuove righe=608835
